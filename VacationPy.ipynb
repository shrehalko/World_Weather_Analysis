# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID        City Country                 Date      Lat      Lng  \
# 0        0  Pittsburgh      US  2022-03-21 17:44:11  40.4406 -79.9959
# 1        1      Austin      US  2022-03-21 17:47:00  30.2672 -97.7431
# 2        2    New York      US  2022-03-21 17:43:37  40.7143 -74.0060
# 3        3  Pittsburgh      US  2022-03-21 17:44:11  40.4406 -79.9959
# 4        4      Austin      US  2022-03-21 17:47:00  30.2672 -97.7431
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     64.15        46           0        5.75
# 1     75.52        88         100       16.11
# 2     61.65        29           0       17.27
# 3     64.15        46           0        5.75
# 4     75.52        88         100       16.11

# %% [markdown]
# #### One caveat to using gmaps: The data we use for any mapping must be either an integer or a floating-point decimal number. Let's check the data types for the columns of our DataFrame.

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# ### Create a Maximum Temperature Heatmap

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %% [markdown]
# #### 1. Assign the locations to an array of latitude and longitude pairs.
# locations = [latitude, longitude]
# #### 2. Assign the weights variable to some values.
# temperatures = # an array of length equal to the locations array length
# #### 3. Assign the figure variable to the gmaps.figure() attribute.
# fig = gmaps.figure()
# #### 4. Assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations.
# heatmap_layer = gmaps.heatmap_layer(locations, weights=temperatures)
# #### 5. Add the heatmap layer.
# fig.add_layer(heatmap_layer)
# #### 6. Call the figure to plot the data.
# fig

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]

# Google heatmaps do not plot negative numbers. If you have a maximum temperature that is less than 0 °F,
# then you will get an InvalidWeightException error for this line of code. Hence we need to plot only temp > 0.
# Get the maximum temperature.
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))
    
# Assign the figure variable.
#fig = gmaps.figure()

#First, add the geographic center of Earth in the form of latitude and longitude (30.0° N and 31.0° E). 
#Also, add a zoom level so that only one map of Earth is shown
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

# Assign the heatmap variable.
#heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)

# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
locations.head()
# Out:
#        Lat       Lng
# 0 -23.1203 -134.9692
# 1 -34.4187   19.2345
# 2 -33.0153   27.9116
# 3 -53.1500  -70.9167
# 4 -54.8000  -68.3000

# %%
max_temp
# Out:
# 0      79.77
# 1      76.80
# 2      74.34
# 3      50.11
# 4      40.62
#        ...
# 552    69.03
# 553    27.14
# 554    -2.76
# 555    83.82
# 556    64.33
# Name: Max Temp, Length: 557, dtype: float64

# %%
temps
# Out:
# [79.77,
#  76.8,
#  74.34,
#  50.11,
#  40.62,
#  82.69,
#  47.64,
#  0,
#  70.27,
#  81.36,
#  44.8,
#  78.78,
#  81.48,
#  0,
#  42.69,
#  73.13,
#  78.85,
#  71.65,
#  81.55,
#  82.2,
#  30.69,
#  83.01,
#  49.66,
#  0,
#  44.47,
#  53.78,
#  45.21,
#  83.28,
#  49.37,
#  77.16,
#  0,
#  67.73,
#  0,
#  78.53,
#  46.38,
#  0,
#  60.28,
#  0,
#  71.65,
#  60.03,
#  54.57,
#  1.15,
#  62.02,
#  63.7,
#  82.78,
#  0,
#  81.99,
#  46.8,
#  77.07,
#  79.11,
#  74.17,
#  61.25,
#  61.68,
#  82.4,
#  0,
#  64.26,
#  49.17,
#  86.0,
#  20.21,
#  85.68,
#  103.68,
#  48.18,
#  81.16,
#  70.29,
#  44.53,
#  49.95,
#  48.72,
#  58.98,
#  77.5,
#  0,
#  86.52,
#  68.49,
#  44.38,
#  77.11,
#  74.52,
#  59.72,
#  36.36,
#  82.65,
#  33.82,
#  10.36,
#  84.72,
#  65.23,
#  77.74,
#  86.05,
#  69.01,
#  54.09,
#  43.93,
#  63.48,
#  59.2,
#  76.37,
#  1.44,
#  67.17,
#  67.96,
#  75.47,
#  79.61,
#  26.58,
#  0,
#  84.15,
#  91.9,
#  57.94,
#  28.08,
#  39.96,
#  30.25,
#  75.45,
#  59.23,
#  50.13,
#  20.79,
#  87.76,
#  86.22,
#  76.35,
#  87.17,
#  71.4,
#  67.01,
#  69.98,
#  84.25,
#  27.97,
#  80.53,
#  69.75,
#  56.71,
#  0,
#  84.2,
#  50.0,
#  91.54,
#  76.19,
#  81.09,
#  74.95,
#  0,
#  80.4,
#  37.24,
#  62.82,
#  73.33,
#  32.85,
#  42.01,
#  41.68,
#  35.11,
#  55.45,
#  64.31,
#  13.75,
#  48.9,
#  82.36,
#  57.49,
#  5.79,
#  86.97,
#  86.07,
#  68.88,
#  62.87,
#  34.7,
#  62.91,
#  78.62,
#  63.9,
#  72.72,
#  84.43,
#  57.7,
#  55.94,
#  83.64,
#  84.29,
#  78.75,
#  78.94,
#  67.98,
#  76.98,
#  52.41,
#  76.75,
#  72.95,
#  71.58,
#  79.88,
#  95.18,
#  0,
#  84.56,
#  40.21,
#  63.82,
#  52.09,
#  73.51,
#  79.39,
#  24.57,
#  52.88,
#  22.33,
#  77.54,
#  21.18,
#  60.64,
#  81.64,
#  79.57,
#  67.12,
#  68.86,
#  67.93,
#  38.66,
#  44.28,
#  71.6,
#  81.09,
#  100.08,
#  58.68,
#  67.57,
#  80.94,
#  0,
#  77.02,
#  86.04,
#  10.31,
#  0,
#  10.31,
#  79.36,
#  85.37,
#  71.33,
#  76.8,
#  77.5,
#  98.8,
#  82.8,
#  67.86,
#  37.38,
#  49.89,
#  5.22,
#  0,
#  39.09,
#  83.55,
#  76.87,
#  100.38,
#  71.02,
#  23.16,
#  61.95,
#  56.1,
#  76.01,
#  64.81,
#  78.37,
#  80.28,
#  78.3,
#  78.19,
#  84.16,
#  79.68,
#  78.46,
#  0,
#  101.61,
#  75.25,
#  61.2,
#  83.28,
#  75.85,
#  97.09,
#  32.99,
#  82.08,
#  76.77,
#  86.56,
#  63.36,
#  43.23,
#  0,
#  66.22,
#  36.18,
#  85.69,
#  62.58,
#  22.53,
#  37.9,
#  83.55,
#  75.7,
#  60.21,
#  75.34,
#  0,
#  78.53,
#  84.94,
#  89.87,
#  19.9,
#  63.84,
#  75.52,
#  0,
#  73.11,
#  31.05,
#  85.46,
#  36.21,
#  89.65,
#  0.19,
#  0,
#  30.52,
#  78.62,
#  69.91,
#  22.75,
#  65.95,
#  84.31,
#  71.89,
#  74.62,
#  58.03,
#  60.57,
#  24.85,
#  83.86,
#  89.47,
#  78.84,
#  54.01,
#  61.21,
#  79.47,
#  68.88,
#  70.21,
#  32.65,
#  27.88,
#  77.4,
#  85.06,
#  73.53,
#  20.68,
#  69.37,
#  83.34,
#  81.09,
#  19.45,
#  68.68,
#  45.7,
#  48.92,
#  77.88,
#  93.58,
#  55.81,
#  91.63,
#  61.56,
#  35.69,
#  55.94,
#  102.88,
#  59.61,
#  0,
#  48.74,
#  80.4,
#  55.9,
#  36.81,
#  1.11,
#  0,
#  74.12,
#  79.12,
#  61.18,
#  86.38,
#  0,
#  70.48,
#  73.27,
#  77.13,
#  85.23,
#  50.77,
#  10.35,
#  73.69,
#  79.92,
#  25.16,
#  35.06,
#  44.08,
#  93.49,
#  89.69,
#  83.62,
#  55.81,
#  80.19,
#  24.33,
#  74.62,
#  0,
#  62.06,
#  37.27,
#  55.26,
#  58.71,
#  82.4,
#  66.7,
#  0,
#  75.09,
#  22.62,
#  28.87,
#  72.7,
#  38.84,
#  44.42,
#  0,
#  78.4,
#  84.04,
#  84.09,
#  41.92,
#  41.18,
#  78.46,
#  48.38,
#  80.28,
#  66.45,
#  64.62,
#  77.32,
#  87.67,
#  79.75,
#  83.01,
#  72.77,
#  0,
#  78.89,
#  81.07,
#  72.57,
#  15.64,
#  82.85,
#  82.35,
#  40.51,
#  60.01,
#  44.49,
#  79.59,
#  70.11,
#  67.77,
#  81.39,
#  76.71,
#  82.51,
#  52.81,
#  50.14,
#  23.25,
#  96.89,
#  0,
#  79.45,
#  7.75,
#  0,
#  80.89,
#  6.67,
#  86.04,
#  0,
#  81.59,
#  81.45,
#  79.56,
#  58.35,
#  80.11,
#  64.92,
#  35.67,
#  0,
#  30.18,
#  66.11,
#  11.79,
#  78.01,
#  79.3,
#  6.87,
#  34.45,
#  75.52,
#  79.02,
#  49.82,
#  80.2,
#  73.4,
#  84.18,
#  75.24,
#  66.88,
#  66.56,
#  73.9,
#  66.02,
#  64.8,
#  85.42,
#  76.39,
#  85.78,
#  79.9,
#  51.12,
#  0,
#  5.68,
#  76.59,
#  3.83,
#  81.21,
#  42.73,
#  57.69,
#  82.0,
#  2.48,
#  76.96,
#  51.28,
#  74.28,
#  84.96,
#  28.53,
#  72.99,
#  67.66,
#  79.63,
#  52.86,
#  70.02,
#  82.44,
#  74.21,
#  84.15,
#  31.95,
#  14.11,
#  76.5,
#  61.52,
#  54.32,
#  90.79,
#  69.98,
#  78.76,
#  0,
#  101.14,
#  43.92,
#  74.93,
#  75.09,
#  82.87,
#  77.81,
#  89.78,
#  0,
#  36.95,
#  80.44,
#  61.36,
#  84.45,
#  78.08,
#  45.88,
#  24.69,
#  20.88,
#  83.89,
#  77.79,
#  101.19,
#  57.65,
#  45.93,
#  81.81,
#  41.77,
#  84.18,
#  73.6,
#  48.61,
#  82.94,
#  75.96,
#  66.04,
#  40.42,
#  84.99,
#  78.94,
#  0,
#  80.37,
#  7.93,
#  84.02,
#  71.38,
#  58.42,
#  51.33,
#  64.27,
#  0.88,
#  81.37,
#  42.89,
#  78.91,
#  44.96,
#  80.42,
#  0,
#  49.44,
#  47.98,
#  78.82,
#  64.94,
#  24.37,
#  58.37,
#  75.36,
#  85.62,
#  62.06,
#  0,
#  87.76,
#  87.49,
#  83.43,
#  63.72,
#  12.61,
#  54.16,
#  40.21,
#  28.18,
#  34.03,
#  85.3,
#  60.44,
#  71.78,
#  44.64,
#  70.97,
#  87.42,
#  91.13,
#  50.18,
#  30.87,
#  35.71,
#  84.7,
#  20.53,
#  81.7,
#  78.21,
#  74.32,
#  74.01,
#  54.01,
#  24.85,
#  67.17,
#  78.82,
#  58.51,
#  20.89,
#  60.28,
#  7.29,
#  86.14,
#  70.81,
#  9.01,
#  84.97,
#  69.03,
#  27.14,
#  0,
#  83.82,
#  64.33]

# %%
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

# %%
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)

# %% [markdown]
# ### Create a Percent Humidity Heatmap

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create a Percent Cloudiness Heatmap

# %%
# Heatmap of percent Percent Cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create a Wind Speed Heatmap

# %%
# Heatmap of percent Wind Speed
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# #### Now, the cherry on top of the project: a feature on the app that allows customers to search for locations they want to travel based on their temperature preferences.
#
# #### Your clients will enter their preferences. Your code will tell them where to travel.

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] >= min_temp) & 
                                       (city_data_df["Max Temp"] <= max_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID                City Country                 Date      Lat  \
# 1         1              Austin      US  2022-03-21 17:47:00  30.2672
# 4         4              Austin      US  2022-03-21 17:47:00  30.2672
# 8         8           Mahebourg      MU  2022-03-21 17:55:37 -20.4081
# 11       11          Vila Velha      BR  2022-03-21 17:51:39 -20.3297
# 12       12  Sao Felix Do Xingu      BR  2022-03-21 17:55:39  -6.6447
# 13       13               Vaini      TO  2022-03-21 17:55:39 -21.2000
# 15       15            Luderitz     NaN  2022-03-21 17:55:40 -26.6481
# 26       26        San Fernando      PH  2022-03-21 17:54:49  15.0286
# 29       29           Taoudenni      ML  2022-03-21 17:55:44  22.6783
# 31       31      Saint-Philippe      RE  2022-03-21 17:55:44 -21.3585
#
#          Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 1   -97.7431     75.52        88         100       16.11
# 4   -97.7431     75.52        88         100       16.11
# 8    57.7000     80.89        89          75        3.44
# 11  -40.2925     82.35        82          20       20.71
# 12  -51.9950     79.95        91          97        0.81
# 13 -175.2000     80.73        79         100       17.20
# 15   15.1594     75.88        62           2       15.86
# 26  120.6898     76.86        78         100        4.21
# 29   -3.9836     86.23        10           0       11.18
# 31   55.7679     78.39        88          95       12.62

# %%
preferred_cities_df.isnull().sum()
# Out:
# City_ID       0
# City          0
# Country       2
# Date          0
# Lat           0
# Lng           0
# Max Temp      0
# Humidity      0
# Cloudiness    0
# Wind Speed    0
# dtype: int64

# %%
preferred_cities_df.count()
# Out:
# City_ID       178
# City          178
# Country       176
# Date          178
# Lat           178
# Lng           178
# Max Temp      178
# Humidity      178
# Cloudiness    178
# Wind Speed    178
# dtype: int64

# %%
preferred_cities_df = preferred_cities_df.dropna()
preferred_cities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 176 entries, 1 to 570
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City_ID     176 non-null    int64
#  1   City        176 non-null    object
#  2   Country     176 non-null    object
#  3   Date        176 non-null    object
#  4   Lat         176 non-null    float64
#  5   Lng         176 non-null    float64
#  6   Max Temp    176 non-null    float64
#  7   Humidity    176 non-null    int64
#  8   Cloudiness  176 non-null    int64
#  9   Wind Speed  176 non-null    float64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 15.1+ KB

# %% [markdown]
# Once the customers have filtered the database (DataFrame) based on their temperature preferences, show them a heatmap for the maximum temperature for the filtered cities. In addition, create a marker for each city that will display the name of the city, country code, maximum temperature, and name of a nearby hotel within three miles of the coordinates when the marker is clicked.

# %% [markdown]
# Using the coordinates from the preferred_cities_df DataFrame, find a hotel using our Google Places API and then retrieve that hotel information. Once we retrieve the hotel information, we'll need to store it so we can reference it and add the information to the pop-up marker.

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                   City Country  Max Temp      Lat       Lng Hotel Name
# 1               Austin      US     75.52  30.2672  -97.7431
# 4               Austin      US     75.52  30.2672  -97.7431
# 8            Mahebourg      MU     80.89 -20.4081   57.7000
# 11          Vila Velha      BR     82.35 -20.3297  -40.2925
# 12  Sao Felix Do Xingu      BR     79.95  -6.6447  -51.9950
# 13               Vaini      TO     80.73 -21.2000 -175.2000
# 26        San Fernando      PH     76.86  15.0286  120.6898
# 29           Taoudenni      ML     86.23  22.6783   -3.9836
# 31      Saint-Philippe      RE     78.39 -21.3585   55.7679
# 37              Lompoc      US     75.56  34.6391 -120.4579

# %% [markdown]
# Using the latitude and longitude and specific parameters, use the Google Places Nearby Search request to retrieve a hotel and add it to the Hotel Name column.

# %%
# Set parameters to search for a hotel.
# The g_key is our Google API key, so be sure to import the config.py file.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %% [markdown]
# Next, add the coordinates for the location parameter for each city, which need to be pulled from the Lat and Lng columns of the hotel_df DataFrame. We'll need to iterate through the columns of the DataFrame and add the coordinates to the params dictionary before making the request and retrieving the JSON data. However, before iterating through the hotel_df DataFrame, we need to know what the JSON data looks like from a search. Let's practice using a fixed latitude and longitude so we understand where to get the hotel name.

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df.head()
# Out:
#                   City Country  Max Temp      Lat      Lng  \
# 1               Austin      US     75.52  30.2672 -97.7431
# 4               Austin      US     75.52  30.2672 -97.7431
# 8            Mahebourg      MU     80.89 -20.4081  57.7000
# 11          Vila Velha      BR     82.35 -20.3297 -40.2925
# 12  Sao Felix Do Xingu      BR     79.95  -6.6447 -51.9950
#
#                                            Hotel Name
# 1   The Driskill - In the Unbound Collection by Hyatt
# 4   The Driskill - In the Unbound Collection by Hyatt
# 8                  Shandrani Beachcomber Resort & Spa
# 11                               Hotel Vitória Palace
# 12                                  Rio Xingu Camping

# %%
hotel_df.isnull().sum()
# Out:
# City          0
# Country       0
# Max Temp      0
# Lat           0
# Lng           0
# Hotel Name    0
# dtype: int64

# %% [markdown]
# Our final task will be to add pop-up markers with hotel information to a heatmap.

# %% [markdown]
# ## Create a Maximum Temperature Heatmap from a Hotel DataFrame

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# Let's add the markers for each city on top of the heatmap. Edit the code we used to create the heatmap to look like the following

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# Now we can add a pop-up marker for each city that displays the hotel name, city name, country, and maximum temperature.

# %% [markdown]
# From the gmaps documentation (https://jupyter-gmaps.readthedocs.io/en/latest/tutorial.html#markers-and-symbols) on how to add markers (Links to an external site.), we need to add an info_box_template that has the following syntax.
# info_box_template = """
# <dl>
# <dt>Name</dt><dd>{column1}</dd>
# <dt>Another name</dt><dd>{column2}</dd>
# </dl>
# """
#
# Description List: <dl>
#     Description Term: <dt>
#         Description Definition: <dd>
#     Description Term: <dt>
#         Description Definition: <dd>

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
hotel_info
# Out:
# ['\n<dl>\n<dt>Hotel Name</dt><dd>The Driskill - In the Unbound Collection by Hyatt</dd>\n<dt>City</dt><dd>Austin</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>75.52 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Driskill - In the Unbound Collection by Hyatt</dd>\n<dt>City</dt><dd>Austin</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>75.52 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shandrani Beachcomber Resort & Spa</dd>\n<dt>City</dt><dd>Mahebourg</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Max Temp</dt><dd>80.89 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Vitória Palace</dd>\n<dt>City</dt><dd>Vila Velha</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>82.35 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Rio Xingu Camping</dd>\n<dt>City</dt><dd>Sao Felix Do Xingu</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>79.95 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Keleti Beach Resort</dd>\n<dt>City</dt><dd>Vaini</dd>\n<dt>Country</dt><dd>TO</dd>\n<dt>Max Temp</dt><dd>80.73 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Maharlika Hostel</dd>\n<dt>City</dt><dd>San Fernando</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>76.86 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Taoudenni</dd>\n<dt>Country</dt><dd>ML</dd>\n<dt>Max Temp</dt><dd>86.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Chambres d\'hôte "La Trinité"</dd>\n<dt>City</dt><dd>Saint-Philippe</dd>\n<dt>Country</dt><dd>RE</dd>\n<dt>Max Temp</dt><dd>78.39 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Holiday Inn Express Lompoc, an IHG Hotel</dd>\n<dt>City</dt><dd>Lompoc</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>75.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Villa Enata</dd>\n<dt>City</dt><dd>Atuona</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>78.51 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Aipana Plaza Hotel</dd>\n<dt>City</dt><dd>Boa Vista</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>89.58 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Taba Hotel</dd>\n<dt>City</dt><dd>Jaciara</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>87.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Executivo Palace</dd>\n<dt>City</dt><dd>Sao Miguel Do Araguaia</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>87.67 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Fengshui Residence</dd>\n<dt>City</dt><dd>Port-Gentil</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Max Temp</dt><dd>82.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Paradise Inn</dd>\n<dt>City</dt><dd>Avarua</dd>\n<dt>Country</dt><dd>CK</dd>\n<dt>Max Temp</dt><dd>80.65 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Cititel Penang</dd>\n<dt>City</dt><dd>Georgetown</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Max Temp</dt><dd>78.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Agapita M. Nicart</dd>\n<dt>City</dt><dd>San Policarpo</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>79.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lindsey Hôtel</dd>\n<dt>City</dt><dd>Saint-Pierre</dd>\n<dt>Country</dt><dd>RE</dd>\n<dt>Max Temp</dt><dd>78.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Isles Sunset Lodge</dd>\n<dt>City</dt><dd>Butaritari</dd>\n<dt>Country</dt><dd>KI</dd>\n<dt>Max Temp</dt><dd>80.26 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tarawa Boutique Hotel</dd>\n<dt>City</dt><dd>Bairiki</dd>\n<dt>Country</dt><dd>KI</dd>\n<dt>Max Temp</dt><dd>80.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Blendana Hotel Assosa</dd>\n<dt>City</dt><dd>Asosa</dd>\n<dt>Country</dt><dd>ET</dd>\n<dt>Max Temp</dt><dd>79.05 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hôtel Le Dronmi</dd>\n<dt>City</dt><dd>Cayenne</dd>\n<dt>Country</dt><dd>GF</dd>\n<dt>Max Temp</dt><dd>86.04 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hôtel Trois Étoiles de Biltine</dd>\n<dt>City</dt><dd>Biltine</dd>\n<dt>Country</dt><dd>TD</dd>\n<dt>Max Temp</dt><dd>87.94 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Foyer ADM</dd>\n<dt>City</dt><dd>Mitsamiouli</dd>\n<dt>Country</dt><dd>KM</dd>\n<dt>Max Temp</dt><dd>79.09 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>People ThankYou</dd>\n<dt>City</dt><dd>Rikitea</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>79.43 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Kost Pria</dd>\n<dt>City</dt><dd>Meulaboh</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>77.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>La visa hotel</dd>\n<dt>City</dt><dd>Peabiru</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>80.11 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>SM TRAVELODGE</dd>\n<dt>City</dt><dd>San Pascual</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>78.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Piesta</dd>\n<dt>City</dt><dd>Trinidad</dd>\n<dt>Country</dt><dd>BO</dd>\n<dt>Max Temp</dt><dd>87.78 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grage Hotel Bengkulu</dd>\n<dt>City</dt><dd>Bengkulu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>75.76 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Timotel Hotel</dd>\n<dt>City</dt><dd>Mersing</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Max Temp</dt><dd>78.71 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hilo Hawaiian Hotel</dd>\n<dt>City</dt><dd>Hilo</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>78.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Tesoro Los Cabos</dd>\n<dt>City</dt><dd>Cabo San Lucas</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>78.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Osprey Beach Hotel</dd>\n<dt>City</dt><dd>Cockburn Town</dd>\n<dt>Country</dt><dd>TC</dd>\n<dt>Max Temp</dt><dd>80.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Embassy Suites by Hilton Dorado del Mar Beach Resort</dd>\n<dt>City</dt><dd>Dorado</dd>\n<dt>Country</dt><dd>PR</dd>\n<dt>Max Temp</dt><dd>85.93 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>RUMBIA RESORT VILLA Paka Terengganu</dd>\n<dt>City</dt><dd>Paka</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Max Temp</dt><dd>76.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Porto Praia</dd>\n<dt>City</dt><dd>Arraial Do Cabo</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>76.96 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Auberge les abou</dd>\n<dt>City</dt><dd>Fomboni</dd>\n<dt>Country</dt><dd>KM</dd>\n<dt>Max Temp</dt><dd>83.26 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Motel 6 Sinton, TX</dd>\n<dt>City</dt><dd>San Patricio</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>84.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Kimbe Bay Hotel</dd>\n<dt>City</dt><dd>Kimbe</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>75.31 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Iglesia La luz del mundo columna y apoyo de la verdad. Batallón antiguo morelos</dd>\n<dt>City</dt><dd>Antiguo Morelos</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>81.45 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>OYO 884 Rumoh PMI Hotel</dd>\n<dt>City</dt><dd>Banda Aceh</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>80.73 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>InterContinental Riyadh, an IHG Hotel</dd>\n<dt>City</dt><dd>Riyadh</dd>\n<dt>Country</dt><dd>SA</dd>\n<dt>Max Temp</dt><dd>77.14 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>BON Hotel Delta</dd>\n<dt>City</dt><dd>Warri</dd>\n<dt>Country</dt><dd>NG</dd>\n<dt>Max Temp</dt><dd>83.52 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Boda</dd>\n<dt>Country</dt><dd>CF</dd>\n<dt>Max Temp</dt><dd>87.58 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Finch Bay Galapagos Hotel</dd>\n<dt>City</dt><dd>Puerto Ayora</dd>\n<dt>Country</dt><dd>EC</dd>\n<dt>Max Temp</dt><dd>85.96 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Adrar</dd>\n<dt>Country</dt><dd>MR</dd>\n<dt>Max Temp</dt><dd>87.46 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>hotel la terminal</dd>\n<dt>City</dt><dd>Ixtapa</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>89.38 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shanti Maurice Resort & Spa</dd>\n<dt>City</dt><dd>Souillac</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Max Temp</dt><dd>80.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Bora-Bora Pearl Beach Resort & Spa</dd>\n<dt>City</dt><dd>Faanui</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>81.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hospitality Carnarvon</dd>\n<dt>City</dt><dd>Carnarvon</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>75.27 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Relais de la Maroto</dd>\n<dt>City</dt><dd>Mahina</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>80.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Carvalhos</dd>\n<dt>City</dt><dd>Orizona</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>82.94 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mini Hotel Central</dd>\n<dt>City</dt><dd>Victoria</dd>\n<dt>Country</dt><dd>HK</dd>\n<dt>Max Temp</dt><dd>76.17 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>SanBiz Lodge</dd>\n<dt>City</dt><dd>Kirakira</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Max Temp</dt><dd>79.59 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel San Isidro Oficial</dd>\n<dt>City</dt><dd>Pisco</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Max Temp</dt><dd>77.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Balandra Hotel</dd>\n<dt>City</dt><dd>Manta</dd>\n<dt>Country</dt><dd>EC</dd>\n<dt>Max Temp</dt><dd>79.03 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel LANDIVAR</dd>\n<dt>City</dt><dd>Caranavi</dd>\n<dt>Country</dt><dd>BO</dd>\n<dt>Max Temp</dt><dd>76.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Aldea del Bazar Hotel and Spa</dd>\n<dt>City</dt><dd>Puerto Escondido</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>88.88 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>East Arnhem Real Estate</dd>\n<dt>City</dt><dd>Nhulunbuy</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>81.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Guesthouse Samotina</dd>\n<dt>City</dt><dd>Pemba</dd>\n<dt>Country</dt><dd>MZ</dd>\n<dt>Max Temp</dt><dd>77.7 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Touring Club</dd>\n<dt>City</dt><dd>Trelew</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Max Temp</dt><dd>76.53 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Scoop Guest House</dd>\n<dt>City</dt><dd>Hithadhoo</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Max Temp</dt><dd>83.84 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sur Plaza Hotel</dd>\n<dt>City</dt><dd>Sur</dd>\n<dt>Country</dt><dd>OM</dd>\n<dt>Max Temp</dt><dd>75.63 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Kununurra</dd>\n<dt>City</dt><dd>Kununurra</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>75.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Esplanade Hotel (Accommodation section closed for refurbishment - Bar, Restaurant & Functions remain open)</dd>\n<dt>City</dt><dd>Port Hedland</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>82.45 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>HOTEL IMAN</dd>\n<dt>City</dt><dd>Nouakchott</dd>\n<dt>Country</dt><dd>MR</dd>\n<dt>Max Temp</dt><dd>78.73 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Dwi Putra Hotel - Ende</dd>\n<dt>City</dt><dd>Ende</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>78.06 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lorengau Harbourside Hotel</dd>\n<dt>City</dt><dd>Lorengau</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>80.46 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Balaji tifen & meals veg & non veg hotel</dd>\n<dt>City</dt><dd>Palasa</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>76.19 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nusa Island Retreat</dd>\n<dt>City</dt><dd>Kavieng</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>81.27 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Calamai Tropica</dd>\n<dt>City</dt><dd>Alim</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>79.88 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>castelo pizzaria</dd>\n<dt>City</dt><dd>Acarau</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>83.93 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>OYO 598 Peony Hotel</dd>\n<dt>City</dt><dd>Cam Ranh</dd>\n<dt>Country</dt><dd>VN</dd>\n<dt>Max Temp</dt><dd>78.76 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>JABIR HOTEL</dd>\n<dt>City</dt><dd>Bandarbeyla</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Max Temp</dt><dd>77.81 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nuli Sapi</dd>\n<dt>City</dt><dd>Samarai</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>82.45 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mercure Padang</dd>\n<dt>City</dt><dd>Padang</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>77.05 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Bungalow 63</dd>\n<dt>City</dt><dd>Hambantota</dd>\n<dt>Country</dt><dd>LK</dd>\n<dt>Max Temp</dt><dd>79.9 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Caonaba</dd>\n<dt>City</dt><dd>Nuevitas</dd>\n<dt>Country</dt><dd>CU</dd>\n<dt>Max Temp</dt><dd>82.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pirineos</dd>\n<dt>City</dt><dd>San Cristobal</dd>\n<dt>Country</dt><dd>VE</dd>\n<dt>Max Temp</dt><dd>77.47 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>João de Barro Hotel</dd>\n<dt>City</dt><dd>Sao Benedito Do Rio Preto</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>84.54 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Crôa Mares Hotel</dd>\n<dt>City</dt><dd>Sao Jose Da Coroa Grande</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>81.84 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Veranda Paul et Virginie Hotel & Spa</dd>\n<dt>City</dt><dd>Grand Gaube</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Max Temp</dt><dd>81.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Guest Hotel</dd>\n<dt>City</dt><dd>Manggar</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>80.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Taloa Heights</dd>\n<dt>City</dt><dd>Alofi</dd>\n<dt>Country</dt><dd>NU</dd>\n<dt>Max Temp</dt><dd>81.39 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Latitude20 Roebourne Village</dd>\n<dt>City</dt><dd>Roebourne</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>86.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Khách Sạn Mường Thanh Luxury Cà Mau</dd>\n<dt>City</dt><dd>Ca Mau</dd>\n<dt>Country</dt><dd>VN</dd>\n<dt>Max Temp</dt><dd>79.39 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada dos Navegantes</dd>\n<dt>City</dt><dd>Caravelas</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>83.46 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel De Paris</dd>\n<dt>City</dt><dd>Bertoua</dd>\n<dt>Country</dt><dd>CM</dd>\n<dt>Max Temp</dt><dd>83.64 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Villa Orphee</dd>\n<dt>City</dt><dd>Les Cayes</dd>\n<dt>Country</dt><dd>HT</dd>\n<dt>Max Temp</dt><dd>84.06 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel los Algarrobos</dd>\n<dt>City</dt><dd>Puerto Baquerizo Moreno</dd>\n<dt>Country</dt><dd>EC</dd>\n<dt>Max Temp</dt><dd>79.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Paradise Bay Resort</dd>\n<dt>City</dt><dd>Ahuimanu</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>75.78 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>HOTEL "SAN JOSE"</dd>\n<dt>City</dt><dd>San Matias</dd>\n<dt>Country</dt><dd>BO</dd>\n<dt>Max Temp</dt><dd>85.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hôtel Djamtum</dd>\n<dt>City</dt><dd>Labe</dd>\n<dt>Country</dt><dd>GN</dd>\n<dt>Max Temp</dt><dd>89.46 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grand Copthorne Waterfront</dd>\n<dt>City</dt><dd>Outram</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Max Temp</dt><dd>82.33 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Casa Grande II</dd>\n<dt>City</dt><dd>Caninde</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>88.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Radisson Grenada Beach Resort</dd>\n<dt>City</dt><dd>Saint-Georges</dd>\n<dt>Country</dt><dd>GD</dd>\n<dt>Max Temp</dt><dd>80.58 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Circuit House</dd>\n<dt>City</dt><dd>Tezu</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>75.99 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>KOPKAR Hotel Bintang Sintuk</dd>\n<dt>City</dt><dd>Bontang</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>79.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Auberge des Cocotiers Boali poste</dd>\n<dt>City</dt><dd>Boali</dd>\n<dt>Country</dt><dd>CF</dd>\n<dt>Max Temp</dt><dd>89.33 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Bungalows El Palmiche</dd>\n<dt>City</dt><dd>Satipo</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Max Temp</dt><dd>86.79 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Tia Villa</dd>\n<dt>City</dt><dd>Bambous Virieux</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Max Temp</dt><dd>80.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel RIKMAN Continental</dd>\n<dt>City</dt><dd>Tura</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>80.06 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>KORBEY D'OR OUEST</dd>\n<dt>City</dt><dd>Le Port</dd>\n<dt>Country</dt><dd>RE</dd>\n<dt>Max Temp</dt><dd>80.26 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lidera</dd>\n<dt>City</dt><dd>Carutapera</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>81.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Apollo</dd>\n<dt>City</dt><dd>Uberlandia</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>81.79 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Carmen</dd>\n<dt>City</dt><dd>Moa</dd>\n<dt>Country</dt><dd>CU</dd>\n<dt>Max Temp</dt><dd>81.63 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hospedaje Lawson</dd>\n<dt>City</dt><dd>Matina</dd>\n<dt>Country</dt><dd>CR</dd>\n<dt>Max Temp</dt><dd>80.47 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Solomon Debebe Hotel</dd>\n<dt>City</dt><dd>Gambela</dd>\n<dt>Country</dt><dd>ET</dd>\n<dt>Max Temp</dt><dd>87.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Heritage Park Hotel</dd>\n<dt>City</dt><dd>Honiara</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Max Temp</dt><dd>77.11 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mystic Sands Beachfront Accommodation</dd>\n<dt>City</dt><dd>Neiafu</dd>\n<dt>Country</dt><dd>TO</dd>\n<dt>Max Temp</dt><dd>82.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pereybere Hotel & Spa</dd>\n<dt>City</dt><dd>Cap Malheureux</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Max Temp</dt><dd>79.47 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tour Eiffel Hotel Benin</dd>\n<dt>City</dt><dd>Porto Novo</dd>\n<dt>Country</dt><dd>BJ</dd>\n<dt>Max Temp</dt><dd>83.77 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Jutai</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>76.32 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Ezequiel</dd>\n<dt>City</dt><dd>Novo Aripuana</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>79.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Raj Bhawan</dd>\n<dt>City</dt><dd>Bela</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>79.81 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Villa Kitzia Huacho</dd>\n<dt>City</dt><dd>Hualmay</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Max Temp</dt><dd>75.25 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Coastline Guest House</dd>\n<dt>City</dt><dd>Arawa</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>75.9 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Butterfly Beach Hotel</dd>\n<dt>City</dt><dd>Oistins</dd>\n<dt>Country</dt><dd>BB</dd>\n<dt>Max Temp</dt><dd>82.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel e Restaurante Uirapuru (Márcio uirapuru )Em São Domingos -Go</dd>\n<dt>City</dt><dd>Sao Domingos</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>85.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ilha Praia Hotel</dd>\n<dt>City</dt><dd>Camocim</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>82.72 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Ultramar</dd>\n<dt>City</dt><dd>Valparaiso</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Max Temp</dt><dd>76.64 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Iftin hotel hobyo</dd>\n<dt>City</dt><dd>Hobyo</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Max Temp</dt><dd>79.5 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Birao</dd>\n<dt>Country</dt><dd>CF</dd>\n<dt>Max Temp</dt><dd>87.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa 7 Punta de Piedra</dd>\n<dt>City</dt><dd>Punta De Piedra</dd>\n<dt>Country</dt><dd>VE</dd>\n<dt>Max Temp</dt><dd>80.47 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Juba</dd>\n<dt>City</dt><dd>Mogadishu</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Max Temp</dt><dd>79.09 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel The Royal Honours</dd>\n<dt>City</dt><dd>Mangrol</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>77.88 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotels in Lakshadweep Islands</dd>\n<dt>City</dt><dd>Kavaratti</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>81.99 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Vahmoneh Lodge Vanimo</dd>\n<dt>City</dt><dd>Vanimo</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>77.41 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Tessalit</dd>\n<dt>Country</dt><dd>ML</dd>\n<dt>Max Temp</dt><dd>83.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tanna Lodge</dd>\n<dt>City</dt><dd>Isangel</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Max Temp</dt><dd>78.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Laxman Lodge</dd>\n<dt>City</dt><dd>Parvatipuram</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>77.07 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>HMHotel</dd>\n<dt>City</dt><dd>Guayaquil</dd>\n<dt>Country</dt><dd>EC</dd>\n<dt>Max Temp</dt><dd>83.95 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Aviador Hotel Boutique</dd>\n<dt>City</dt><dd>Santa Cruz</dd>\n<dt>Country</dt><dd>BO</dd>\n<dt>Max Temp</dt><dd>87.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Amaloh Boutique Resort</dd>\n<dt>City</dt><dd>Matara</dd>\n<dt>Country</dt><dd>LK</dd>\n<dt>Max Temp</dt><dd>79.41 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Salinas Park Resort Maçarico AP101</dd>\n<dt>City</dt><dd>Salinopolis</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>80.67 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lakeway Resort & Spa</dd>\n<dt>City</dt><dd>Lakeway</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>75.0 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Ha'apai Beach Resort</dd>\n<dt>City</dt><dd>Pangai</dd>\n<dt>Country</dt><dd>TO</dd>\n<dt>Max Temp</dt><dd>82.22 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>ALETHEIA Appartement Sinnamary</dd>\n<dt>City</dt><dd>Sinnamary</dd>\n<dt>Country</dt><dd>GF</dd>\n<dt>Max Temp</dt><dd>78.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Julfi Home</dd>\n<dt>City</dt><dd>Chapar</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>78.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Cáliz Hostel Chazuta</dd>\n<dt>City</dt><dd>Chazuta</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Max Temp</dt><dd>76.05 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Iglesia morava renovada</dd>\n<dt>City</dt><dd>Iralaya</dd>\n<dt>Country</dt><dd>HN</dd>\n<dt>Max Temp</dt><dd>82.9 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel GSA</dd>\n<dt>City</dt><dd>Santa Isabel Do Rio Negro</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>82.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Puri Brata</dd>\n<dt>City</dt><dd>Srandakan</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>78.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Maui Seaside Hotel</dd>\n<dt>City</dt><dd>Kahului</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>77.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Novotel Phuket Resort</dd>\n<dt>City</dt><dd>Kathu</dd>\n<dt>Country</dt><dd>TH</dd>\n<dt>Max Temp</dt><dd>84.74 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Maringe Lagoon Lodge</dd>\n<dt>City</dt><dd>Buala</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Max Temp</dt><dd>78.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>EPIC SANA Luanda</dd>\n<dt>City</dt><dd>Luanda</dd>\n<dt>Country</dt><dd>AO</dd>\n<dt>Max Temp</dt><dd>82.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Screensaver</dd>\n<dt>City</dt><dd>Harper</dd>\n<dt>Country</dt><dd>LR</dd>\n<dt>Max Temp</dt><dd>82.22 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Amit Jain majholi</dd>\n<dt>City</dt><dd>Majholi</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>83.07 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Swiss-Belhotel Ambon</dd>\n<dt>City</dt><dd>Ambon</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>78.94 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Auberge Tembina Betaré Oya</dd>\n<dt>City</dt><dd>Betare Oya</dd>\n<dt>Country</dt><dd>CM</dd>\n<dt>Max Temp</dt><dd>84.16 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Palms Hotel</dd>\n<dt>City</dt><dd>Beruwala</dd>\n<dt>Country</dt><dd>LK</dd>\n<dt>Max Temp</dt><dd>80.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Villa Park Hotel | Natal</dd>\n<dt>City</dt><dd>Natal</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>83.05 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Amazonie Découverte SARL</dd>\n<dt>City</dt><dd>Roura</dd>\n<dt>Country</dt><dd>GF</dd>\n<dt>Max Temp</dt><dd>84.11 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Costa</dd>\n<dt>City</dt><dd>Riachao Das Neves</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>84.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nyah Lasem | Museum, Warung & Community Center</dd>\n<dt>City</dt><dd>Lasem</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>76.17 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Manuk Mangkaw</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>80.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>INN NEW HORIZON</dd>\n<dt>City</dt><dd>Touros</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>84.9 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Plaza de Armas Bellavista de La Unión</dd>\n<dt>City</dt><dd>Bernal</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Max Temp</dt><dd>82.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa do Kiwliks</dd>\n<dt>City</dt><dd>Pauini</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>80.04 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>casa do bruno</dd>\n<dt>City</dt><dd>Arinos</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>86.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Seagulls Inn Namatani</dd>\n<dt>City</dt><dd>Namatanai</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>79.03 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hospedaje Costa Bella</dd>\n<dt>City</dt><dd>Sechura</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Max Temp</dt><dd>79.25 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>San Borja</dd>\n<dt>Country</dt><dd>BO</dd>\n<dt>Max Temp</dt><dd>86.11 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Conrad Bora Bora Nui</dd>\n<dt>City</dt><dd>Vaitape</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>81.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Puri Brata</dd>\n<dt>City</dt><dd>Bambanglipuro</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>78.19 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>OYO 90038 Dalyla Inn Chalet</dd>\n<dt>City</dt><dd>Cukai</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Max Temp</dt><dd>78.73 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Khách sạn Hải Âu Quy Nhơn - Seagull Hotel</dd>\n<dt>City</dt><dd>Qui Nhon</dd>\n<dt>Country</dt><dd>VN</dd>\n<dt>Max Temp</dt><dd>77.27 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Cj's Travellers Inn</dd>\n<dt>City</dt><dd>Gigmoto</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>79.45 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Flamingo</dd>\n<dt>City</dt><dd>Quelimane</dd>\n<dt>Country</dt><dd>MZ</dd>\n<dt>Max Temp</dt><dd>76.95 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sea Lounge! Bar, Club & Restaurant</dd>\n<dt>City</dt><dd>Itarema</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>84.16 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Humacao Bed & Breakfast</dd>\n<dt>City</dt><dd>Vallenar</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Max Temp</dt><dd>84.25 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Bendang Lama</dd>\n<dt>City</dt><dd>Perbaungan</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>80.71 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Porto Santana</dd>\n<dt>City</dt><dd>Santana</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>78.98 °F</dd>\n</dl>\n']

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
