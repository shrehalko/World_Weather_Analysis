# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

import gmaps

# %% [markdown]
# ### To ensure enough latitudes and longitudes, we'll start with2000. In addition, we'll pack the latitudes (lats) and longitudes (lngs) as pairs by zipping them (lat_lngs) with the zip() function

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
print(lat_lngs)
# Out:
# <zip object at 0x0000017F6FF59F08>

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# #### The citipy module finds the nearest city to the latitude and longitude pair with a population of 500 or more.

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# When we run the cell, the output will be a URL. Click the URL, and a new window will open in your default web browser. 
# The URL will return a 400 message because we haven't added a city to our URL

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# If the status_code is something other than 200, JSON data will always be returned in the request. We can determine if the response was successful by checking the status_code, clicking the URL, or retrieving specific information from the JSON data

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #print(city_url)
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
   # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | padang
# Processing Record 3 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 1 | egvekinot
# Processing Record 5 of Set 1 | te anau
# Processing Record 6 of Set 1 | goderich
# Processing Record 7 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 1 | havoysund
# Processing Record 9 of Set 1 | mar del plata
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | gold coast
# Processing Record 12 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 13 of Set 1 | saldanha
# Processing Record 14 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 1 | gushikawa
# Processing Record 16 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 1 | takoradi
# Processing Record 18 of Set 1 | lavrentiya
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | artyom
# Processing Record 22 of Set 1 | leningradskiy
# Processing Record 23 of Set 1 | bairiki
# Processing Record 24 of Set 1 | hofn
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | yelizovo
# Processing Record 29 of Set 1 | nome
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | puquio
# Processing Record 32 of Set 1 | thongwa
# Processing Record 33 of Set 1 | lagoa
# Processing Record 34 of Set 1 | camacupa
# Processing Record 35 of Set 1 | okha
# Processing Record 36 of Set 1 | floro
# Processing Record 37 of Set 1 | comodoro rivadavia
# Processing Record 38 of Set 1 | mudyuga
# City not found. Skipping...
# Processing Record 39 of Set 1 | saint-raymond
# Processing Record 40 of Set 1 | basyanovskiy
# City not found. Skipping...
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | severo-kurilsk
# Processing Record 43 of Set 1 | tabuk
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | longyearbyen
# Processing Record 46 of Set 1 | chokurdakh
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | klaksvik
# Processing Record 49 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 1 | lichuan
# Processing Record 1 of Set 2 | tuktoyaktuk
# Processing Record 2 of Set 2 | kijang
# Processing Record 3 of Set 2 | tuatapere
# Processing Record 4 of Set 2 | ntungamo
# Processing Record 5 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 7 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 2 | faanui
# Processing Record 9 of Set 2 | neuquen
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | capesterre-belle-eau
# Processing Record 12 of Set 2 | vila velha
# Processing Record 13 of Set 2 | pangai
# Processing Record 14 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 2 | hasaki
# Processing Record 16 of Set 2 | haapiti
# Processing Record 17 of Set 2 | victoria
# Processing Record 18 of Set 2 | poum
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | uruzgan
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | kawalu
# Processing Record 23 of Set 2 | manjacaze
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | kodiak
# Processing Record 26 of Set 2 | georgetown
# Processing Record 27 of Set 2 | bosaso
# Processing Record 28 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 29 of Set 2 | esperance
# Processing Record 30 of Set 2 | fez
# Processing Record 31 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 32 of Set 2 | souillac
# Processing Record 33 of Set 2 | dhidhdhoo
# Processing Record 34 of Set 2 | prince rupert
# Processing Record 35 of Set 2 | brae
# Processing Record 36 of Set 2 | lebu
# Processing Record 37 of Set 2 | hamilton
# Processing Record 38 of Set 2 | yeniseysk
# Processing Record 39 of Set 2 | elblag
# Processing Record 40 of Set 2 | garissa
# Processing Record 41 of Set 2 | iqaluit
# Processing Record 42 of Set 2 | ambon
# Processing Record 43 of Set 2 | chuy
# Processing Record 44 of Set 2 | dasoguz
# Processing Record 45 of Set 2 | arraial do cabo
# Processing Record 46 of Set 2 | hobart
# Processing Record 47 of Set 2 | qaanaaq
# Processing Record 48 of Set 2 | yima
# Processing Record 49 of Set 2 | yulara
# Processing Record 50 of Set 2 | bambous virieux
# Processing Record 1 of Set 3 | saint-philippe
# Processing Record 2 of Set 3 | pangody
# Processing Record 3 of Set 3 | bethel
# Processing Record 4 of Set 3 | hermanus
# Processing Record 5 of Set 3 | ullal
# Processing Record 6 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | saiha
# Processing Record 10 of Set 3 | guiberoua
# Processing Record 11 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 12 of Set 3 | tiksi
# Processing Record 13 of Set 3 | pevek
# Processing Record 14 of Set 3 | khatanga
# Processing Record 15 of Set 3 | akdepe
# Processing Record 16 of Set 3 | krasnogorodsk
# Processing Record 17 of Set 3 | beloha
# Processing Record 18 of Set 3 | albany
# Processing Record 19 of Set 3 | amuntai
# Processing Record 20 of Set 3 | vaini
# Processing Record 21 of Set 3 | talcahuano
# Processing Record 22 of Set 3 | vardo
# Processing Record 23 of Set 3 | bluff
# Processing Record 24 of Set 3 | were ilu
# Processing Record 25 of Set 3 | mutsu
# Processing Record 26 of Set 3 | leibnitz
# Processing Record 27 of Set 3 | talnakh
# Processing Record 28 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 3 | sinnamary
# Processing Record 30 of Set 3 | sydney mines
# Processing Record 31 of Set 3 | vao
# Processing Record 32 of Set 3 | oistins
# Processing Record 33 of Set 3 | kapaa
# Processing Record 34 of Set 3 | carnarvon
# Processing Record 35 of Set 3 | mount gambier
# Processing Record 36 of Set 3 | airai
# Processing Record 37 of Set 3 | tripoli
# Processing Record 38 of Set 3 | marzuq
# Processing Record 39 of Set 3 | melo
# Processing Record 40 of Set 3 | newport
# Processing Record 41 of Set 3 | dingle
# Processing Record 42 of Set 3 | saskylakh
# Processing Record 43 of Set 3 | san
# Processing Record 44 of Set 3 | atuona
# Processing Record 45 of Set 3 | tessalit
# Processing Record 46 of Set 3 | riyadh
# Processing Record 47 of Set 3 | shimoda
# Processing Record 48 of Set 3 | quatre cocos
# Processing Record 49 of Set 3 | kloulklubed
# Processing Record 50 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 4 | castres
# Processing Record 2 of Set 4 | atyrau
# Processing Record 3 of Set 4 | monrovia
# Processing Record 4 of Set 4 | ribeira grande
# Processing Record 5 of Set 4 | uvelskiy
# Processing Record 6 of Set 4 | peleduy
# Processing Record 7 of Set 4 | makarska
# Processing Record 8 of Set 4 | sobolevo
# Processing Record 9 of Set 4 | kropotkin
# Processing Record 10 of Set 4 | hithadhoo
# Processing Record 11 of Set 4 | polson
# Processing Record 12 of Set 4 | nanakuli
# Processing Record 13 of Set 4 | palmer
# Processing Record 14 of Set 4 | sao joao da barra
# Processing Record 15 of Set 4 | saint george
# Processing Record 16 of Set 4 | barrow
# Processing Record 17 of Set 4 | port elizabeth
# Processing Record 18 of Set 4 | portland
# Processing Record 19 of Set 4 | flinders
# Processing Record 20 of Set 4 | kamenka
# Processing Record 21 of Set 4 | korla
# Processing Record 22 of Set 4 | codrington
# Processing Record 23 of Set 4 | davila
# Processing Record 24 of Set 4 | kenai
# Processing Record 25 of Set 4 | jiayuguan
# Processing Record 26 of Set 4 | mazagao
# Processing Record 27 of Set 4 | san jose del guaviare
# Processing Record 28 of Set 4 | vuktyl
# Processing Record 29 of Set 4 | astoria
# Processing Record 30 of Set 4 | adrar
# Processing Record 31 of Set 4 | dzaoudzi
# Processing Record 32 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 34 of Set 4 | alofi
# Processing Record 35 of Set 4 | san cristobal
# Processing Record 36 of Set 4 | katangli
# Processing Record 37 of Set 4 | sao filipe
# Processing Record 38 of Set 4 | norman wells
# Processing Record 39 of Set 4 | bandarbeyla
# Processing Record 40 of Set 4 | ust-nera
# Processing Record 41 of Set 4 | college
# Processing Record 42 of Set 4 | am timan
# Processing Record 43 of Set 4 | slave lake
# Processing Record 44 of Set 4 | vestmanna
# Processing Record 45 of Set 4 | chiguiri arriba
# City not found. Skipping...
# Processing Record 46 of Set 4 | bengkulu
# Processing Record 47 of Set 4 | pauini
# Processing Record 48 of Set 4 | wattegama
# Processing Record 49 of Set 4 | obera
# Processing Record 50 of Set 4 | onega
# Processing Record 1 of Set 5 | saint-pascal
# City not found. Skipping...
# Processing Record 2 of Set 5 | provideniya
# Processing Record 3 of Set 5 | nantucket
# Processing Record 4 of Set 5 | banda aceh
# Processing Record 5 of Set 5 | bonthe
# Processing Record 6 of Set 5 | avarua
# Processing Record 7 of Set 5 | ilulissat
# Processing Record 8 of Set 5 | barhi
# Processing Record 9 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 5 | kitimat
# Processing Record 11 of Set 5 | kemin
# Processing Record 12 of Set 5 | san-pedro
# Processing Record 13 of Set 5 | pisco
# Processing Record 14 of Set 5 | ranong
# Processing Record 15 of Set 5 | aitape
# Processing Record 16 of Set 5 | hailar
# Processing Record 17 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 5 | yumen
# Processing Record 19 of Set 5 | sri aman
# Processing Record 20 of Set 5 | canarana
# Processing Record 21 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 5 | bilma
# Processing Record 23 of Set 5 | wilmington island
# Processing Record 24 of Set 5 | mount isa
# Processing Record 25 of Set 5 | ongandjera
# Processing Record 26 of Set 5 | miami
# Processing Record 27 of Set 5 | grand gaube
# Processing Record 28 of Set 5 | les cayes
# Processing Record 29 of Set 5 | tazovskiy
# Processing Record 30 of Set 5 | vasteras
# Processing Record 31 of Set 5 | sur
# Processing Record 32 of Set 5 | saint anthony
# Processing Record 33 of Set 5 | naze
# Processing Record 34 of Set 5 | turukhansk
# Processing Record 35 of Set 5 | inongo
# Processing Record 36 of Set 5 | sinjah
# City not found. Skipping...
# Processing Record 37 of Set 5 | najran
# Processing Record 38 of Set 5 | juba
# Processing Record 39 of Set 5 | knysna
# Processing Record 40 of Set 5 | bismarck
# Processing Record 41 of Set 5 | butaritari
# Processing Record 42 of Set 5 | aljezur
# Processing Record 43 of Set 5 | ponta do sol
# Processing Record 44 of Set 5 | liuzhou
# Processing Record 45 of Set 5 | srandakan
# Processing Record 46 of Set 5 | nikolayevsk-na-amure
# Processing Record 47 of Set 5 | chegdomyn
# Processing Record 48 of Set 5 | buchanan
# Processing Record 49 of Set 5 | spring hill
# Processing Record 50 of Set 5 | axim
# Processing Record 1 of Set 6 | danjiangkou
# Processing Record 2 of Set 6 | torbay
# Processing Record 3 of Set 6 | lupiro
# Processing Record 4 of Set 6 | lata
# Processing Record 5 of Set 6 | fontanka
# Processing Record 6 of Set 6 | tortoli
# Processing Record 7 of Set 6 | shoreview
# Processing Record 8 of Set 6 | dongsheng
# Processing Record 9 of Set 6 | harper
# Processing Record 10 of Set 6 | accra
# Processing Record 11 of Set 6 | uyuni
# Processing Record 12 of Set 6 | ucluelet
# Processing Record 13 of Set 6 | vostok
# Processing Record 14 of Set 6 | salinas
# Processing Record 15 of Set 6 | upernavik
# Processing Record 16 of Set 6 | karla
# Processing Record 17 of Set 6 | westport
# Processing Record 18 of Set 6 | makat
# Processing Record 19 of Set 6 | east chicago
# Processing Record 20 of Set 6 | bulgan
# Processing Record 21 of Set 6 | puerto baquerizo moreno
# Processing Record 22 of Set 6 | deputatskiy
# Processing Record 23 of Set 6 | antigonish
# Processing Record 24 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 25 of Set 6 | cidreira
# Processing Record 26 of Set 6 | bathsheba
# Processing Record 27 of Set 6 | mantua
# Processing Record 28 of Set 6 | luderitz
# Processing Record 29 of Set 6 | lenki
# City not found. Skipping...
# Processing Record 30 of Set 6 | horsham
# Processing Record 31 of Set 6 | new norfolk
# Processing Record 32 of Set 6 | guerrero negro
# Processing Record 33 of Set 6 | san patricio
# Processing Record 34 of Set 6 | krasnyy chikoy
# Processing Record 35 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 6 | lubango
# Processing Record 37 of Set 6 | nanortalik
# Processing Record 38 of Set 6 | dzilam gonzalez
# Processing Record 39 of Set 6 | haines junction
# Processing Record 40 of Set 6 | ust-maya
# Processing Record 41 of Set 6 | matamoros
# Processing Record 42 of Set 6 | tukrah
# Processing Record 43 of Set 6 | epe
# Processing Record 44 of Set 6 | fortuna
# Processing Record 45 of Set 6 | mackay
# Processing Record 46 of Set 6 | puerto carreno
# Processing Record 47 of Set 6 | sitka
# Processing Record 48 of Set 6 | mojo
# Processing Record 49 of Set 6 | baiyin
# Processing Record 50 of Set 6 | khonsa
# Processing Record 1 of Set 7 | katsuura
# Processing Record 2 of Set 7 | dabat
# Processing Record 3 of Set 7 | dikson
# Processing Record 4 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 7 | sigiriya
# Processing Record 6 of Set 7 | port-gentil
# Processing Record 7 of Set 7 | largu
# Processing Record 8 of Set 7 | acapulco
# Processing Record 9 of Set 7 | vila franca do campo
# Processing Record 10 of Set 7 | mangit
# Processing Record 11 of Set 7 | kahului
# Processing Record 12 of Set 7 | kaitangata
# Processing Record 13 of Set 7 | avera
# Processing Record 14 of Set 7 | coahuayana
# Processing Record 15 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 7 | salta
# Processing Record 17 of Set 7 | salalah
# Processing Record 18 of Set 7 | mayumba
# Processing Record 19 of Set 7 | qasigiannguit
# Processing Record 20 of Set 7 | ocean city
# Processing Record 21 of Set 7 | mithi
# Processing Record 22 of Set 7 | vallenar
# Processing Record 23 of Set 7 | mae sai
# Processing Record 24 of Set 7 | port lincoln
# Processing Record 25 of Set 7 | faya
# Processing Record 26 of Set 7 | rantoul
# Processing Record 27 of Set 7 | north platte
# Processing Record 28 of Set 7 | neos marmaras
# Processing Record 29 of Set 7 | nikolskoye
# Processing Record 30 of Set 7 | auki
# Processing Record 31 of Set 7 | japura
# Processing Record 32 of Set 7 | porosozero
# Processing Record 33 of Set 7 | katherine
# Processing Record 34 of Set 7 | aasiaat
# Processing Record 35 of Set 7 | tezu
# Processing Record 36 of Set 7 | pelym
# Processing Record 37 of Set 7 | olafsvik
# Processing Record 38 of Set 7 | berezovka
# Processing Record 39 of Set 7 | ahipara
# Processing Record 40 of Set 7 | samagaltay
# Processing Record 41 of Set 7 | cabatuan
# Processing Record 42 of Set 7 | tafresh
# Processing Record 43 of Set 7 | suzu
# City not found. Skipping...
# Processing Record 44 of Set 7 | anadyr
# Processing Record 45 of Set 7 | forbes
# Processing Record 46 of Set 7 | pangnirtung
# Processing Record 47 of Set 7 | mazamari
# Processing Record 48 of Set 7 | taburi
# City not found. Skipping...
# Processing Record 49 of Set 7 | jiangyou
# Processing Record 50 of Set 7 | port hedland
# Processing Record 1 of Set 8 | takaka
# Processing Record 2 of Set 8 | batagay-alyta
# Processing Record 3 of Set 8 | saint-joseph
# Processing Record 4 of Set 8 | lucapa
# Processing Record 5 of Set 8 | husavik
# Processing Record 6 of Set 8 | mbanza-ngungu
# Processing Record 7 of Set 8 | ixtapa
# Processing Record 8 of Set 8 | santa isabel do rio negro
# Processing Record 9 of Set 8 | rio grande
# Processing Record 10 of Set 8 | okhotsk
# Processing Record 11 of Set 8 | broken hill
# Processing Record 12 of Set 8 | port moresby
# Processing Record 13 of Set 8 | alekseyevka
# Processing Record 14 of Set 8 | skjervoy
# Processing Record 15 of Set 8 | sabha
# Processing Record 16 of Set 8 | kaeo
# Processing Record 17 of Set 8 | mehamn
# Processing Record 18 of Set 8 | patea
# Processing Record 19 of Set 8 | ugoofaaru
# Processing Record 20 of Set 8 | jawhar
# Processing Record 21 of Set 8 | twentynine palms
# Processing Record 22 of Set 8 | zhezkazgan
# Processing Record 23 of Set 8 | butterworth
# Processing Record 24 of Set 8 | laguna
# Processing Record 25 of Set 8 | cap malheureux
# Processing Record 26 of Set 8 | malakal
# Processing Record 27 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 28 of Set 8 | koslan
# Processing Record 29 of Set 8 | sao jose da coroa grande
# Processing Record 30 of Set 8 | mahebourg
# Processing Record 31 of Set 8 | manbij
# Processing Record 32 of Set 8 | kangaba
# Processing Record 33 of Set 8 | nizwa
# Processing Record 34 of Set 8 | tilichiki
# Processing Record 35 of Set 8 | swan river
# Processing Record 36 of Set 8 | ola
# Processing Record 37 of Set 8 | aklavik
# Processing Record 38 of Set 8 | yambio
# Processing Record 39 of Set 8 | senanga
# Processing Record 40 of Set 8 | huntington
# Processing Record 41 of Set 8 | toulepleu
# City not found. Skipping...
# Processing Record 42 of Set 8 | ryotsu
# Processing Record 43 of Set 8 | jalu
# Processing Record 44 of Set 8 | bukama
# Processing Record 45 of Set 8 | vreed en hoop
# City not found. Skipping...
# Processing Record 46 of Set 8 | anloga
# Processing Record 47 of Set 8 | san isidro
# Processing Record 48 of Set 8 | zeya
# Processing Record 49 of Set 8 | lakes entrance
# Processing Record 50 of Set 8 | mandeville
# Processing Record 1 of Set 9 | hameln
# Processing Record 2 of Set 9 | turtkul
# City not found. Skipping...
# Processing Record 3 of Set 9 | sinop
# Processing Record 4 of Set 9 | belmonte
# Processing Record 5 of Set 9 | esil
# Processing Record 6 of Set 9 | zarya
# Processing Record 7 of Set 9 | vestmannaeyjar
# Processing Record 8 of Set 9 | tumut
# Processing Record 9 of Set 9 | gualeguaychu
# Processing Record 10 of Set 9 | makakilo city
# Processing Record 11 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 9 | hwange
# Processing Record 13 of Set 9 | berdigestyakh
# Processing Record 14 of Set 9 | nuristan
# Processing Record 15 of Set 9 | zmeinogorsk
# Processing Record 16 of Set 9 | vangaindrano
# Processing Record 17 of Set 9 | kyaikkami
# Processing Record 18 of Set 9 | south lake tahoe
# Processing Record 19 of Set 9 | teknaf
# Processing Record 20 of Set 9 | coquimbo
# Processing Record 21 of Set 9 | pocoes
# Processing Record 22 of Set 9 | daxian
# City not found. Skipping...
# Processing Record 23 of Set 9 | batouri
# Processing Record 24 of Set 9 | zapolyarnyy
# Processing Record 25 of Set 9 | kangaatsiaq
# Processing Record 26 of Set 9 | kaspiyskiy
# Processing Record 27 of Set 9 | maragogi
# Processing Record 28 of Set 9 | labrea
# Processing Record 29 of Set 9 | sangmelima
# Processing Record 30 of Set 9 | sikeston
# Processing Record 31 of Set 9 | tasiilaq
# Processing Record 32 of Set 9 | hami
# Processing Record 33 of Set 9 | kruisfontein
# Processing Record 34 of Set 9 | pitimbu
# Processing Record 35 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 36 of Set 9 | gravdal
# Processing Record 37 of Set 9 | hobyo
# Processing Record 38 of Set 9 | pacific grove
# Processing Record 39 of Set 9 | morant bay
# Processing Record 40 of Set 9 | trinidad
# Processing Record 41 of Set 9 | dhemaji
# Processing Record 42 of Set 9 | constitucion
# Processing Record 43 of Set 9 | coihaique
# Processing Record 44 of Set 9 | ambovombe
# Processing Record 45 of Set 9 | soc trang
# Processing Record 46 of Set 9 | povorino
# Processing Record 47 of Set 9 | praia da vitoria
# Processing Record 48 of Set 9 | celestun
# Processing Record 49 of Set 9 | viesca
# Processing Record 50 of Set 9 | karratha
# Processing Record 1 of Set 10 | porto novo
# Processing Record 2 of Set 10 | hirara
# Processing Record 3 of Set 10 | kanigiri
# Processing Record 4 of Set 10 | guacimo
# Processing Record 5 of Set 10 | fallon
# Processing Record 6 of Set 10 | muros
# Processing Record 7 of Set 10 | chiman
# Processing Record 8 of Set 10 | warrnambool
# Processing Record 9 of Set 10 | novosergiyevka
# Processing Record 10 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 10 | ndele
# Processing Record 12 of Set 10 | cayenne
# Processing Record 13 of Set 10 | kavieng
# Processing Record 14 of Set 10 | rincon
# Processing Record 15 of Set 10 | geraldton
# Processing Record 16 of Set 10 | broome
# Processing Record 17 of Set 10 | houma
# Processing Record 18 of Set 10 | goure
# Processing Record 19 of Set 10 | irtyshskiy
# Processing Record 20 of Set 10 | tocantins
# Processing Record 21 of Set 10 | krasnoselkup
# Processing Record 22 of Set 10 | pochinki
# Processing Record 23 of Set 10 | cairns
# Processing Record 24 of Set 10 | skegness
# Processing Record 25 of Set 10 | la ronge
# Processing Record 26 of Set 10 | cururupu
# Processing Record 27 of Set 10 | elko
# Processing Record 28 of Set 10 | clyde river
# Processing Record 29 of Set 10 | merritt
# Processing Record 30 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 10 | nikolayevskaya
# Processing Record 32 of Set 10 | belle fourche
# Processing Record 33 of Set 10 | yar-sale
# Processing Record 34 of Set 10 | young
# Processing Record 35 of Set 10 | barranca de upia
# Processing Record 36 of Set 10 | namikupa
# Processing Record 37 of Set 10 | khotyn
# Processing Record 38 of Set 10 | los llanos de aridane
# Processing Record 39 of Set 10 | ambulu
# Processing Record 40 of Set 10 | cherskiy
# Processing Record 41 of Set 10 | smidovich
# Processing Record 42 of Set 10 | berlevag
# Processing Record 43 of Set 10 | rocha
# Processing Record 44 of Set 10 | lasa
# Processing Record 45 of Set 10 | messina
# Processing Record 46 of Set 10 | baishishan
# Processing Record 47 of Set 10 | zhaoyuan
# Processing Record 48 of Set 10 | bayaguana
# Processing Record 49 of Set 10 | kiunga
# Processing Record 50 of Set 10 | greensburg
# Processing Record 1 of Set 11 | ingham
# Processing Record 2 of Set 11 | ferme-neuve
# Processing Record 3 of Set 11 | ancud
# Processing Record 4 of Set 11 | galle
# Processing Record 5 of Set 11 | shenjiamen
# Processing Record 6 of Set 11 | beypur
# City not found. Skipping...
# Processing Record 7 of Set 11 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 8 of Set 11 | wolmaranstad
# City not found. Skipping...
# Processing Record 9 of Set 11 | tateyama
# Processing Record 10 of Set 11 | suhbaatar
# Processing Record 11 of Set 11 | ankazobe
# Processing Record 12 of Set 11 | marsh harbour
# Processing Record 13 of Set 11 | komsomolskiy
# Processing Record 14 of Set 11 | santa maria del oro
# Processing Record 15 of Set 11 | sept-iles
# Processing Record 16 of Set 11 | qandala
# Processing Record 17 of Set 11 | rabo de peixe
# Processing Record 18 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 19 of Set 11 | byron bay
# Processing Record 20 of Set 11 | antalaha
# Processing Record 21 of Set 11 | plettenberg bay
# Processing Record 22 of Set 11 | utica
# Processing Record 23 of Set 11 | presidencia roque saenz pena
# Processing Record 24 of Set 11 | provost
# Processing Record 25 of Set 11 | kyra
# Processing Record 26 of Set 11 | derzhavinsk
# Processing Record 27 of Set 11 | mogadishu
# Processing Record 28 of Set 11 | joniskis
# Processing Record 29 of Set 11 | zheleznodorozhnyy
# Processing Record 30 of Set 11 | holme
# Processing Record 31 of Set 11 | huaiyuan
# Processing Record 32 of Set 11 | anjiang
# Processing Record 33 of Set 11 | praya
# Processing Record 34 of Set 11 | caconda
# Processing Record 35 of Set 11 | curup
# Processing Record 36 of Set 11 | griffith
# Processing Record 37 of Set 11 | topdac
# Processing Record 38 of Set 11 | callaway
# Processing Record 39 of Set 11 | ust-ilimsk
# Processing Record 40 of Set 11 | sarramea
# Processing Record 41 of Set 11 | paamiut
# Processing Record 42 of Set 11 | daru
# Processing Record 43 of Set 11 | nicolae balcescu
# Processing Record 44 of Set 11 | zhob
# Processing Record 45 of Set 11 | dwarka
# Processing Record 46 of Set 11 | ornskoldsvik
# Processing Record 47 of Set 11 | boa vista
# Processing Record 48 of Set 11 | marmora
# Processing Record 49 of Set 11 | porto belo
# Processing Record 50 of Set 11 | narsaq
# Processing Record 1 of Set 12 | ergani
# Processing Record 2 of Set 12 | rio negrinho
# Processing Record 3 of Set 12 | elk grove
# Processing Record 4 of Set 12 | zhigansk
# Processing Record 5 of Set 12 | viedma
# Processing Record 6 of Set 12 | kourou
# Processing Record 7 of Set 12 | aden
# Processing Record 8 of Set 12 | skovde
# City not found. Skipping...
# Processing Record 9 of Set 12 | catamarca
# Processing Record 10 of Set 12 | chimore
# Processing Record 11 of Set 12 | lorengau
# Processing Record 12 of Set 12 | jacmel
# Processing Record 13 of Set 12 | samarai
# Processing Record 14 of Set 12 | borazjan
# Processing Record 15 of Set 12 | codajas
# Processing Record 16 of Set 12 | sabzevar
# Processing Record 17 of Set 12 | port blair
# Processing Record 18 of Set 12 | inuvik
# Processing Record 19 of Set 12 | preobrazheniye
# Processing Record 20 of Set 12 | caribou
# Processing Record 21 of Set 12 | fernie
# Processing Record 22 of Set 12 | roald
# Processing Record 23 of Set 12 | georgiyevka
# Processing Record 24 of Set 12 | carutapera
# Processing Record 25 of Set 12 | coos bay
# Processing Record 26 of Set 12 | ishigaki
# Processing Record 27 of Set 12 | jahrom
# City not found. Skipping...
# Processing Record 28 of Set 12 | khorixas
# Processing Record 29 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 30 of Set 12 | kvarkeno
# Processing Record 31 of Set 12 | arnold
# Processing Record 32 of Set 12 | mujiayingzi
# Processing Record 33 of Set 12 | necochea
# Processing Record 34 of Set 12 | taicheng
# Processing Record 35 of Set 12 | caravelas
# Processing Record 36 of Set 12 | eyl
# Processing Record 37 of Set 12 | vizinga
# Processing Record 38 of Set 12 | nadvoitsy
# Processing Record 39 of Set 12 | palana
# Processing Record 40 of Set 12 | nabire
# Processing Record 41 of Set 12 | ayia marina
# Processing Record 42 of Set 12 | nuuk
# Processing Record 43 of Set 12 | moose jaw
# Processing Record 44 of Set 12 | greytown
# Processing Record 45 of Set 12 | chumikan
# Processing Record 46 of Set 12 | kununurra
# Processing Record 47 of Set 12 | bitung
# Processing Record 48 of Set 12 | airdrie
# Processing Record 49 of Set 12 | toora-khem
# Processing Record 50 of Set 12 | jaru
# Processing Record 1 of Set 13 | charters towers
# Processing Record 2 of Set 13 | sao joao do paraiso
# Processing Record 3 of Set 13 | shagonar
# Processing Record 4 of Set 13 | maraa
# Processing Record 5 of Set 13 | bartica
# Processing Record 6 of Set 13 | sao felix do xingu
# Processing Record 7 of Set 13 | namibe
# Processing Record 8 of Set 13 | panalingaan
# Processing Record 9 of Set 13 | ewa beach
# Processing Record 10 of Set 13 | cozumel
# Processing Record 11 of Set 13 | smolenka
# Processing Record 12 of Set 13 | ostrovnoy
# Processing Record 13 of Set 13 | bayan
# Processing Record 14 of Set 13 | kaduna
# Processing Record 15 of Set 13 | myski
# Processing Record 16 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 17 of Set 13 | asfi
# Processing Record 18 of Set 13 | businga
# Processing Record 19 of Set 13 | graaff-reinet
# Processing Record 20 of Set 13 | atar
# Processing Record 21 of Set 13 | dire
# Processing Record 22 of Set 13 | palmares do sul
# Processing Record 23 of Set 13 | paithan
# Processing Record 24 of Set 13 | champerico
# Processing Record 25 of Set 13 | camana
# Processing Record 26 of Set 13 | ketchikan
# Processing Record 27 of Set 13 | la rioja
# Processing Record 28 of Set 13 | ballarat
# Processing Record 29 of Set 13 | mahanoro
# Processing Record 30 of Set 13 | pansoy
# Processing Record 31 of Set 13 | mayo
# Processing Record 32 of Set 13 | itoman
# Processing Record 33 of Set 13 | pala
# Processing Record 34 of Set 13 | dong xoai
# Processing Record 35 of Set 13 | bardiyah
# Processing Record 36 of Set 13 | gumdag
# Processing Record 37 of Set 13 | salinopolis
# Processing Record 38 of Set 13 | santa rita
# Processing Record 39 of Set 13 | redmond
# Processing Record 40 of Set 13 | tofield
# Processing Record 41 of Set 13 | bichura
# Processing Record 42 of Set 13 | shumskiy
# Processing Record 43 of Set 13 | morondava
# Processing Record 44 of Set 13 | margate
# Processing Record 45 of Set 13 | loningen
# Processing Record 46 of Set 13 | bagdarin
# Processing Record 47 of Set 13 | oktyabrskiy
# Processing Record 48 of Set 13 | vanimo
# Processing Record 49 of Set 13 | yanji
# Processing Record 50 of Set 13 | a
# City not found. Skipping...
# Processing Record 1 of Set 14 | lompoc
# Processing Record 2 of Set 14 | oranjemund
# Processing Record 3 of Set 14 | fenoarivo
# Processing Record 4 of Set 14 | koppies
# Processing Record 5 of Set 14 | srednekolymsk
# Processing Record 6 of Set 14 | da nang
# Processing Record 7 of Set 14 | mongo
# Processing Record 8 of Set 14 | usinsk
# Processing Record 9 of Set 14 | ust-barguzin
# Processing Record 10 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 11 of Set 14 | meybod
# Processing Record 12 of Set 14 | sistranda
# Processing Record 13 of Set 14 | luganville
# Processing Record 14 of Set 14 | macin
# Processing Record 15 of Set 14 | erenhot
# Processing Record 16 of Set 14 | novyy urengoy
# Processing Record 17 of Set 14 | asenovgrad
# Processing Record 18 of Set 14 | hot springs
# Processing Record 19 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 14 | liwonde
# Processing Record 21 of Set 14 | sanhsia
# City not found. Skipping...
# Processing Record 22 of Set 14 | mormugao
# Processing Record 23 of Set 14 | muravlenko
# Processing Record 24 of Set 14 | rudbar
# Processing Record 25 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 14 | puerto penasco
# Processing Record 27 of Set 14 | chimbote
# Processing Record 28 of Set 14 | novikovo
# Processing Record 29 of Set 14 | taoudenni
# Processing Record 30 of Set 14 | buala
# Processing Record 31 of Set 14 | nizhniy baskunchak
# Processing Record 32 of Set 14 | mersing
# Processing Record 33 of Set 14 | maravilha
# Processing Record 34 of Set 14 | saint-pierre
# Processing Record 35 of Set 14 | kampot
# Processing Record 36 of Set 14 | cayambe
# Processing Record 37 of Set 14 | fukue
# Processing Record 38 of Set 14 | tautira
# Processing Record 39 of Set 14 | urshelskiy
# Processing Record 40 of Set 14 | taonan
# Processing Record 41 of Set 14 | cloquet
# Processing Record 42 of Set 14 | edgewater
# Processing Record 43 of Set 14 | tifton
# Processing Record 44 of Set 14 | caraguatatuba
# Processing Record 45 of Set 14 | hovd
# Processing Record 46 of Set 14 | nkpor
# Processing Record 47 of Set 14 | at-bashi
# Processing Record 48 of Set 14 | kuusamo
# Processing Record 49 of Set 14 | salon-de-provence
# Processing Record 50 of Set 14 | kulynychi
# Processing Record 1 of Set 15 | aguimes
# Processing Record 2 of Set 15 | montepuez
# Processing Record 3 of Set 15 | farmington
# Processing Record 4 of Set 15 | kedrovyy
# Processing Record 5 of Set 15 | caraballeda
# Processing Record 6 of Set 15 | mangrol
# Processing Record 7 of Set 15 | inhambane
# Processing Record 8 of Set 15 | tucuman
# Processing Record 9 of Set 15 | xuddur
# Processing Record 10 of Set 15 | lyuban
# Processing Record 11 of Set 15 | uige
# Processing Record 12 of Set 15 | bowen
# Processing Record 13 of Set 15 | khirkiya
# Processing Record 14 of Set 15 | kautokeino
# Processing Record 15 of Set 15 | king city
# Processing Record 16 of Set 15 | sokolo
# Processing Record 17 of Set 15 | asau
# Processing Record 18 of Set 15 | muyezerskiy
# Processing Record 19 of Set 15 | nauta
# Processing Record 20 of Set 15 | markova
# Processing Record 21 of Set 15 | piacabucu
# Processing Record 22 of Set 15 | cherdyn
# Processing Record 23 of Set 15 | namuac
# Processing Record 24 of Set 15 | atasu
# Processing Record 25 of Set 15 | biltine
# Processing Record 26 of Set 15 | half moon bay
# Processing Record 27 of Set 15 | skibbereen
# Processing Record 28 of Set 15 | saran
# Processing Record 29 of Set 15 | blagoyevo
# Processing Record 30 of Set 15 | aykhal
# Processing Record 31 of Set 15 | dombarovskiy
# Processing Record 32 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 15 | owasso
# Processing Record 34 of Set 15 | maloy
# Processing Record 35 of Set 15 | yaizu
# Processing Record 36 of Set 15 | gat
# Processing Record 37 of Set 15 | xichang
# Processing Record 38 of Set 15 | honningsvag
# Processing Record 39 of Set 15 | jaciara
# Processing Record 40 of Set 15 | meaford
# Processing Record 41 of Set 15 | andijon
# Processing Record 42 of Set 15 | haradok
# Processing Record 43 of Set 15 | harbour breton
# Processing Record 44 of Set 15 | vikhorevka
# Processing Record 45 of Set 15 | farsund
# Processing Record 46 of Set 15 | puerto el triunfo
# Processing Record 47 of Set 15 | renqiu
# Processing Record 48 of Set 15 | muhos
# Processing Record 49 of Set 15 | beaupre
# Processing Record 50 of Set 15 | todos santos
# Processing Record 1 of Set 16 | williston
# Processing Record 2 of Set 16 | paso de los toros
# Processing Record 3 of Set 16 | longonjo
# Processing Record 4 of Set 16 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 5 of Set 16 | monster
# Processing Record 6 of Set 16 | guilin
# Processing Record 7 of Set 16 | gorontalo
# Processing Record 8 of Set 16 | moose factory
# Processing Record 9 of Set 16 | ginda
# Processing Record 10 of Set 16 | maniitsoq
# Processing Record 11 of Set 16 | darab
# Processing Record 12 of Set 16 | mpanda
# Processing Record 13 of Set 16 | kushmurun
# Processing Record 14 of Set 16 | chara
# Processing Record 15 of Set 16 | saint-francois
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 707 entries, 0 to 706
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 707 non-null    object
#  1   Lat                  707 non-null    float64
#  2   Lng                  707 non-null    float64
#  3   Max Temp             707 non-null    float64
#  4   Humidity             707 non-null    int64
#  5   Cloudiness           707 non-null    int64
#  6   Wind Speed           707 non-null    float64
#  7   Current Description  707 non-null    object
#  8   Country              707 non-null    object
#  9   Date                 707 non-null    object
# dtypes: float64(4), int64(2), object(4)
# memory usage: 55.4+ KB

# %%
city_data_df.tail()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 702           Darab  28.7519   54.5444     64.36        31           0
# 703          Mpanda  -6.3655   31.0409     64.44        95          57
# 704       Kushmurun  52.4503   64.6311     15.10        91          91
# 705           Chara  56.9064  118.2631      8.13        80          99
# 706  Saint-Francois  46.4154    3.9054     45.68        52           0
#
#      Wind Speed Current Description Country                 Date
# 702        2.71           clear sky      IR  2022-03-22 20:20:33
# 703        2.68       broken clouds      TZ  2022-03-22 20:20:33
# 704       10.76     overcast clouds      KZ  2022-03-22 20:20:34
# 705        0.98     overcast clouds      RU  2022-03-22 20:20:34
# 706        8.05           clear sky      FR  2022-03-22 20:20:34

# %%
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Rikitea -23.1203 -134.9692     79.39        70          66       12.10
# 1     Padang  -0.9492  100.3543     76.82        86          84        3.76
# 2  Egvekinot  66.3167 -179.1667     10.87        97         100        1.86
# 3    Te Anau -45.4167  167.7167     56.26        84           9        0.81
# 4   Goderich  43.7501  -81.7165     39.90        57         100        8.14
#
#     Current Description Country                 Date
# 0         broken clouds      PF  2022-03-22 20:01:32
# 1  heavy intensity rain      ID  2022-03-22 20:01:32
# 2       overcast clouds      RU  2022-03-22 20:01:33
# 3             clear sky      NZ  2022-03-22 20:01:33
# 4       overcast clouds      CA  2022-03-22 20:01:20

# %%
new_column_order = [ "City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
